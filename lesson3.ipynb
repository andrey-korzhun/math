# %% [markdown]
# # Выполнение практическое задание по теме “Введение в аналитическую геометрию”
#
# ## 1. Задание
# Даны два вектора в трехмерном пространстве: (10,10,10) и (0,0,-10)
# ##### 1)	Найдите их сумму. (на листочке)

# %% [markdown]
# $$
# \begin{equation*}
#     \begin{bmatrix}
#         10\\
#         10\\
#         10\\
#     \end{bmatrix}
#      +
#     \begin{bmatrix}
#         0\\
#         0\\
#         -10\\
#      \end{bmatrix}
#      =
#     \begin{bmatrix}
#         10 \\
#         10\\
#         0\\
#      \end{bmatrix}
# \end{equation*}
# $$

# %% [markdown]
# ##### 2)	Напишите код на Python, реализующий расчет длины вектора, заданного его координатами. (в программе)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patches as patches
import math
from math import sqrt
from array import *
from pylab import *
from mpl_toolkits.mplot3d import Axes3D

# %%
coords = []
i = 1
while i <= 3:
    coords.append(float(input(f'Input coordinate #{i}:')))
    i += 1
x, y, z = coords
vector_lenth = math.sqrt(x * x + y * y + z * z)
print(f'Lenght of vector: {vector_lenth}')
# Out:
# Input coordinate #1:10
# Input coordinate #2:10
# Input coordinate #3:10
# Lenght of vector: 17.320508075688775

# %% [markdown]
# ## 2. Задание (на листочке)
# Почему прямые не кажутся перпендикулярными? (см.ролик)

# %%
x = np.linspace(-5, 5, 21)
y = 3*x+1
y2 = (-1/3)*x+1
plt.plot(x,y)
plt.plot(x,y2)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# Выравним масштаб осей

# %%
x = np.linspace(-5, 5, 21)
y = 3*x+1
y2 = (-1/3)*x+1

plt.figure(figsize=(6, 6))
plt.xlim (-15, 15)
plt.ylim (-15, 15)
plt.plot(x,y)
plt.plot(x,y2)
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# #### Ответ: Отличался масштаб осей

# %% [markdown]
# ## 3. Задание (в программе)
# Напишите код на Python, реализующий построение графиков:
# ##### 1.	окружности

# %%
r = 1

fig, ax = plt.subplots()
circ = patches.Circle((0, 0), r, alpha=0.8, fill=False)
ax.add_patch(circ)
ax.set_xlim(-r - 0.1 * r, r + 0.1 * r)
ax.set_ylim(-r - 0.1 * r, r + 0.1 * r)
ax.set_aspect(1.0)

# %% [markdown]
# ##### 2. эллипса

# %%
width = 2
height = 1
angle = 45

fig, ax = plt.subplots()
circ = patches.Ellipse((0, 0), width, height, angle=angle, alpha=0.8, fill=False)
ax.add_patch(circ)
if width > height:
    r = width / 2
else:
    r = height / 2
ax.set_xlim(-r - 0.1 * r, r + 0.1 * r)
ax.set_ylim(-r - 0.1 * r, r + 0.1 * r)
ax.set_aspect(1.0)

# %% [markdown]
# ##### 3. гиперболы

# %%
xmin = -20
xmax = 20
dx = 0.1

xlist = np.around(np.arange(xmin, xmax, dx), decimals=4)
ylist = 1 / xlist

plt.plot(xlist, ylist)
# Out:
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in true_divide

# %% [markdown]
# ## 4. Задание (на листочке)
# ##### 1) Пусть задана плоскость:
# $$ Ax+By+Cz+D=0$$
#
# Напишите уравнение плоскости, параллельной данной и проходящей через начало координат.
#
# ##### Ответ: $$ Ax+By+Cz=0$$

# %%
fig = figure()
ax = Axes3D(fig)
ax.view_init(30, -45)
X = np.arange(-5, 5, 1)
Y = np.arange(-5, 5, 1)
X, Y = np.meshgrid(X, Y)
Z = (-1*X - 2*Y - 40)/3
Z1 = (-1*X - 2*Y)/3
ax.plot_wireframe(X, Y, Z)
ax.plot_wireframe(X, Y, Z1)
ax.scatter(0, 0, 0,'z',50,'red')

# %% [markdown]
# ##### 2)  Пусть задана плоскость: A1x + B1y + C1z + D1 = 0
# и прямая:$$\frac{x-x_1}{x_2-x_1}=\frac{y-y_1}{y_2-y_1}=\frac{z-z_1}{z_2-z_1} $$
#
# Как узнать, принадлежит прямая плоскости или нет?
# ##### Ответ:

# %% [markdown]
# Прямая проходит через две точки (x1, y1) и (x2, y2). Если плоскость проходит через эти же 2 точки, то прямая принадлежит плоскости. Плоскость будет проходить черех заданные точки только при условии выполнении системы уравнений:
#
# $$
#  \begin{cases}
#   A1(x-x_1)+B1(y-y_1)+C1(z-z_1)+D1=0\\
#   A1(x_2-x_1)+B1(y_2-y_1)+C1(z_2-z_1)+D1=0
#  \end{cases}
# $$
#
# Таким образом, если данная система имеет решение, то прямая принадлежит плоскости

# %% [markdown]
# ## 5. Задание (в программе)
# ##### 1)	Нарисуйте трехмерный график двух параллельных плоскостей.

# %%
fig = figure()
ax = Axes3D(fig)
ax.view_init(30, -45)
X = np.arange(-5, 5, 2)
Y = np.arange(-5, 5, 2)
X, Y = np.meshgrid(X, Y)
Z = (-2*X - 3*Y - 40)/4
Z1 = (-2*X - 3*Y)/4
ax.plot_surface(X, Y, Z)
ax.plot_surface(X, Y, Z1)

# %% [markdown]
# ##### 2)	Нарисуйте трехмерный график двух любых поверхностей второго порядка.

# %%
fig = figure()
ax = Axes3D(fig)
ax.view_init(30, -45)
X = np.arange(-100, 100, 10)
Y = np.arange(-50, 50, 10)
X, Y = np.meshgrid(X, Y)
Z = (-2*X**2 + 3*Y**2 - 40)/4
Z1 = (2*X**2 + 3*Y**2)/4
ax.plot_surface(X, Y, Z)
ax.plot_surface(X, Y, Z1)
