# %% [markdown]
# # Выполнение практического задания по теме  “Графики на плоскости"
#
# ## 1. Задание
# Нарисуйте график функции:
# y(x) = k∙cos(x – a) + b
# для некоторых (2-3 различных) значений параметров k, a, b

# %%
import numpy as np
from math import sqrt
from array import *
import matplotlib.pyplot as plt
import math
import matplotlib.ticker as ticker
from pylab import *
from scipy.optimize import fsolve

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 128)
plt.subplots(figsize=(10, 5))
plt.grid(True)
param = [(1, 2, 3), (2, 3, 1), (3, 1, 2)]
for k, a, b in param:
    y = k*np.cos(x - a) + b
    plt.plot(x, y)

# %% [markdown]
# ## 2. Задание
# Докажите, что при ортогональном преобразовании сохраняется расстояние между точками.

# %% [markdown]
# ##### Доказательство
# Ортогональные преобразования сохраняют длины и углы.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3. Задание (в программе)
# ##### 1.	Напишите код, который будет переводить полярные координаты в декартовы.

# %%
def polar_to_cartesian(r, f):
    f = f * np.pi / 180
    x = np.cos(f) * r
    y = np.sin(f) * r
    return np.around([x, y], decimals=2)

polar_to_cartesian(1, 90)
# Out:
# array([0., 1.])

# %% [markdown]
# ##### 2.	Напишите код, который будет рисовать график окружности в полярных координатах.

# %%
x = np.linspace(0, 2*np.pi, 100)
y = np.full(100, 5)

plt.polar(x, y)

# %% [markdown]
# ##### 3.	Напишите код, который будет рисовать график отрезка прямой линии в полярных координатах.

# %%
x = np.linspace(0, np.pi/2, 2)
y =(3.5, 3)
plt.polar(x, y)

# %% [markdown]
# ## 4. Задание (в программе)
# ##### 1)	Решите систему уравнений:
# $$
#  \begin{cases}
#   y = x^2 – 1\\
#   exp(x) + x∙(1 – y) = 1
#  \end{cases}
# $$

# %%
def draw_lines():
    plt.axvline(x=x1, color='g', linestyle='--', linewidth=0.5)
    plt.axhline(y=y1, color='g', linestyle='--', linewidth=0.5)

    plt.axvline(x=x2, color='b', linestyle='--', linewidth=0.5)
    plt.axhline(y=y2, color='b', linestyle='--', linewidth=0.5)

    plt.axvline(x=x3, color='y', linestyle='--', linewidth=0.5)
    plt.axhline(y=y3, color='y', linestyle='--', linewidth=0.5)

# %%
x = np.linspace(-50, 50, 500)
plt.figure(figsize=(8,8))
plt.ylim(-1, 25)
plt.xlim(-5, 5)
plt.plot(x, x**2-1, label='y=x**2-1')
plt.plot(x, np.exp(x)/x + 1 - 1/x, label='y=exp(x)/x + 1 - 1/x')

x1, y1 = (-3, 5)
x2, y2 = (1.8, 2.8)
x3, y3 = (3.8, 13)

draw_lines()

plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# %%
def equasions(p):
    x, y = p
    return (x**2 - 1 - y, np.exp(x)/x + 1 - 1/x - y)

x1, y1 = fsolve(equasions, (x1, y1))
x2, y2 = fsolve(equasions, (x2, y2))
x3, y3 = fsolve(equasions, (x3, y3))

print('Ответ:')
print(f'x1={x1:.2f}, y1={y1:.2f}')
print(f'x2={x2:.2f}, y2={y2:.2f}')
print(f'x3={x3:.2f}, y3={y3:.2f}')
# Out:
# Ответ:
# x1=-1.58, y1=1.50
# x2=2.62, y2=5.85
# x3=4.20, y3=16.64

# %%
x = np.linspace(-50, 50, 500)
plt.figure(figsize=(8,8))
plt.ylim(-1, 25)
plt.xlim(-5, 5)
plt.plot(x, x**2-1, label='y=x**2-1')
plt.plot(x, np.exp(x)/x + 1 - 1/x, label='y=exp(x)/x + 1 - 1/x')

draw_lines()

plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# %% [markdown]
# ##### 2)	Решите систему уравнений и неравенств:
#  $$
#  \begin{cases}
#   y = x^2 – 1\\
#   exp(x) + x∙(1 – y) > 1
#  \end{cases}
# $$

# %%
print(f'x1={x1:.2f}, y1={y1:.2f}')
print(f'x2={x2:.2f}, y2={y2:.2f}')
print(f'x3={x3:.2f}, y3={y3:.2f}')
# Out:
# x1=-1.58, y1=1.50
# x2=2.62, y2=5.85
# x3=4.20, y3=16.64

# %% [markdown]
# Решением данной системы будут следующие множества x и y:
# $$
# \begin{cases}
# x\subset((-\infty; -1.58)\cup(2.62; 4.20))\\
# y\subset((1.50; +\infty)\cup(5.85; 16.64))
# \end{cases}
# $$
